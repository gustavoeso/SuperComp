# %% [markdown]
# ## Aula 1: A importância da linguagem

# %% [markdown]
# #### Gustavo Eliziario Stevenson de Oliveira

# %%
########### 15 iteracoes ###########
sem_otimizacoes_15 = 0
otimizacao_basica_15 = 0
otimizacao_padrao_15 = 0
otimizacao_avancada_15 = 0

print("Python 200: ", sem_otimizacoes_15)
print("C++ normal 200: ", otimizacao_basica_15)
print("C++ paralelo 200: ", otimizacao_avancada_15)

########### 30 iteracoes ###########
python_300 = 2.42
cpp_normal_300 = 0.145646
cpp_parale_300 = 0.0451638

print("Python 300: ", python_300)
print("C++ normal 300: ", cpp_normal_300)
print("C++ paralelo 300: ", cpp_parale_300)

########### 50 iteracoes ###########
python_900 = 69.56
cpp_normal_900 = 4.03359
cpp_parale_900 = 1.17564

print("Python 900: ", python_900)
print("C++ normal 900: ", cpp_normal_900)
print("C++ paralelo 900: ", cpp_parale_900)

########### 100 iteracoes ###########
python_1300 = 223.18
cpp_normal_1300 = 12.4792
cpp_parale_1300 = 3.21539

print("Python 1300: ", python_1300)
print("C++ normal 1300: ", cpp_normal_1300)
print("C++ paralelo 1300: ", cpp_parale_1300)
# Out:
# Python 200:  0.69
# C++ normal 200:  0.0432353
# C++ paralelo 200:  0.013165
# Python 300:  2.42
# C++ normal 300:  0.145646
# C++ paralelo 300:  0.0451638
# Python 900:  69.56
# C++ normal 900:  4.03359
# C++ paralelo 900:  1.17564
# Python 1300:  223.18
# C++ normal 1300:  12.4792
# C++ paralelo 1300:  3.21539

# %%
import matplotlib.pyplot as plt

# Matrix sizes
matrix_sizes = [200, 300, 900, 1300]

# Performance values
python_performance = [python_200, python_300, python_900, python_1300]
cpp_normal_performance = [cpp_normal_200, cpp_normal_300, cpp_normal_900, cpp_normal_1300]
cpp_parale_performance = [cpp_parale_200, cpp_parale_300, cpp_parale_900, cpp_parale_1300]

# Plotting
plt.figure(figsize=(12, 6))

plt.plot(matrix_sizes, python_performance, label='Python', marker='o')
plt.plot(matrix_sizes, cpp_normal_performance, label='C++ Normal', marker='o')
plt.plot(matrix_sizes, cpp_parale_performance, label='C++ Paralelo', marker='o')

plt.xlabel('Tamanho da Matriz')
plt.ylabel('Tempo de Execução (s)')
plt.title('Comparação de Performance entre Python e C++')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# #### _Discuta o impacto do ambiente HPC no desempenho das operações e como o paralelismo pode escalar em um cluster de múltiplos nós._
#
# O HPC tem um desempenho nítidamente melhor quando paralelizado, diferente de quando estavamos rodando localmente, onde o paralelizado e normal em C++ nao tinha quase diferença nenhuma. Utilizando HPC, onde a paralelização pode realmente ocorrer por conta do cluster com desempenho de nós, fazendo ele ter um desempenho melhor que um codigo normal.
