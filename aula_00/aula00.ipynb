# %% [markdown]
# ## Aula 0: A importância da linguagem

# %% [markdown]
# #### Gustavo Eliziario Stevenson de Oliveira

# %%
########### matriz 200 ###########
python_200 = (0.63+0.65+0.67)/3
cpp_normal_200 = (0.0443632+0.0582144+0.0628728)/3
cpp_parale_200 = (0.0542505+0.0592348+0.0597672)/3

print("Python 200: ", python_200)
print("C++ normal 200: ", cpp_normal_200)
print("C++ paralelo 200: ", cpp_parale_200)

########### matriz 300 ###########
python_300 = (2.54+2.5+2.28)/3
cpp_normal_300 = (0.166896+0.15992+0.176145)/3
cpp_parale_300 = (0.201635+0.164848+0.171253)/3

print("Python 300: ", python_300)
print("C++ normal 300: ", cpp_normal_300)
print("C++ paralelo 300: ", cpp_parale_300)

########### matriz 900 ###########
python_900 = 79.62
cpp_normal_900 = 4.38314
cpp_parale_900 = 4.11258

print("Python 900: ", python_900)
print("C++ normal 900: ", cpp_normal_900)
print("C++ paralelo 900: ", cpp_parale_900)

########### matriz 1300 ###########
python_1300 = 235.56
cpp_normal_1300 = 12.8401
cpp_parale_1300 = 12.714

print("Python 1300: ", python_1300)
print("C++ normal 1300: ", cpp_normal_1300)
print("C++ paralelo 1300: ", cpp_parale_1300)
# Out:
# Python 200:  0.65
# C++ normal 200:  0.05515013333333333
# C++ paralelo 200:  0.057750833333333335
# Python 300:  2.44
# C++ normal 300:  0.16765366666666667
# C++ paralelo 300:  0.17924533333333334
# Python 900:  79.62
# C++ normal 900:  4.38314
# C++ paralelo 900:  4.11258
# Python 1300:  235.56
# C++ normal 1300:  12.8401
# C++ paralelo 1300:  12.714

# %%
import matplotlib.pyplot as plt

# Matrix sizes
matrix_sizes = [200, 300, 900, 1300]

# Performance values
python_performance = [python_200, python_300, python_900, python_1300]
cpp_normal_performance = [cpp_normal_200, cpp_normal_300, cpp_normal_900, cpp_normal_1300]
cpp_parale_performance = [cpp_parale_200, cpp_parale_300, cpp_parale_900, cpp_parale_1300]

# Plotting
plt.figure(figsize=(12, 6))

plt.plot(matrix_sizes, python_performance, label='Python', marker='o')
plt.plot(matrix_sizes, cpp_normal_performance, label='C++ Normal', marker='o')
plt.plot(matrix_sizes, cpp_parale_performance, label='C++ Paralelo', marker='o')

plt.xlabel('Tamanho da Matriz')
plt.ylabel('Tempo de Execução (s)')
plt.title('Comparação de Performance entre Python e C++')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# #### _Faça uma análise comparativa sobre o impacto do paralelismo no desempenho de acordo com a complexidade do problema._
#
# No caso desse problema por ser menos complexo, nao conseguimos ver uma grande diferença de desempenho entre o paralelismo e o codigo normal em C++. Isso pode ser por conta da matriz não ser grande o suficiente para conseguirmos ver uma diferença significativa, se a matriz fosse maior, o paralelismo provavelmente teria um desempenho melhor que o codigo normal por conta de conseguir dividir o trabalho entre os threads.

# %% [markdown]
# ##### _Comente sobre como você acha que este problema pode ser abordado em um ambiente de HPC._
#
# Em um ambiente de HPC *(High Performance Computer)*, o problema poderia ser abordado de forma mais eficiente, pois o paralelismo poderia ser melhor explorado, dividindo o trabalho entre os threads de forma mais eficiente e mais quantidade de threads, o que poderia resultar em um desempenho melhor do que o codigo normal em um ambiente que não é um HPC.
